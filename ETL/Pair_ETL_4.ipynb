# %%
import pandas as pd
import mysql.connector
import numpy as np

# %% [markdown]
# Es el momento de meter todos nuestros datos en SQL 💪🏽!!! En este ejercicio nos crearemos dos tablas en una BBDD creada por nosotras. Una de las tablas contendrá la información que obtuvimos de los ejercicios de pair programming de Limpieza, es decir, el data set de ataques de tiburones limpito. La segunda tabla tendrá la información obtenida en el ejercicio de pair de ETL 1.
# - 📌 Nota Todo lo tendremos que hacer desde jupyter notebook
# - Cread la BBDD con el nombre de tiburones.
# - Cread las tablas de la BBDD:
# - Tabla ataques
# - Tabla clima
# - BONUS Insertar los datos en las tablas.
# 📌 Nota Esta parte del pair es optativa y no será considerada para la evaluación
# 🚨 En caso de que no tengáis los datos unidos de la sesión anterior, tenéis un csv datos_union_clima_ataques con todos los datos que necesitareis para este ejercicio

# %%
#Decidimos usar el cvs que nos dais porque cuando empezamos este pair no teníamos los datos juntados.

df = pd.read_csv("datos/datos_union_clima_ataques.csv", index_col=0)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head(2)
# Out:
#   case_number    year        type country        area  \
# 0  2018.06.25  2018.0     Boating     USA  California
# 1  2018.06.18  2018.0  Unprovoked     USA     Georgia
#
#                          location  activity              name age  \
# 0     Oceanside, San Diego County  Paddling       Julie Wolfe  57
# 1  St. Simon Island, Glynn County  Standing  AdysonÂ McNeely   11
#
#             time     species_  \
# 0          18h00  White shark
# 1  14h00  -15h00          NaN
#
#                                               injury fecha_limpia fatal sex  \
# 0  No injury to occupant, outrigger canoe and pad...          Jun     N   F
# 1                         Minor injury to left thigh          Jun     N   F
#
#   pais  rh_950mb  rh_900mb  rh_850mb  rh_800mb  rh_750mb  rh_700mb  rh_650mb  \
# 0  USA  4.953125   6.15625    6.8125  6.296875   5.03125  5.296875  5.234375
# 1  USA  4.953125   6.15625    6.8125  6.296875   5.03125  5.296875  5.234375
#
# ...

# %%
def crear_bbdd(nombre_bbdd):
    mydb = mysql.connector.connect(
                                    host= "localhost", 
                                    user= "root",
                                    password= "AlumnaAdalab")

    print("conexion realizada con éxito")

    mycursor = mydb.cursor()
    try:
        mycursor.execute(f"CREATE DATABASE IF NOT EXISTS {nombre_bbdd};")
        print(mycursor)

    except mysql.connector.Error as err:

        print(err)
        print("error code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# %%
mybase = crear_bbdd("tiburones")
# Out:
# conexion realizada con éxito
# CMySQLCursor: CREATE DATABASE IF NOT EXISTS tiburones;

# %%
def crear_insertar_tabla(nombre_bbdd, query):

    cnx = mysql.connector.connect(user= "root", password= f"AlumnaAdalab", host= "127.0.0.1", database = f"{nombre_bbdd}" )

    mycursor = cnx.cursor()

    try:
        mycursor.execute(query)
        cnx.commit()

    except mysql.connector.Error as err:

        print(err)
        print("error code:", err.errno)
        print("SQLSTATE", err.sqlstate)
        print("Message", err.msg)

# %%
#Sacamos un columns y un info para ver los datos de la tabla y crear la query.

df.columns
# Out:
# Index(['case_number', 'year', 'type', 'country', 'area', 'location',
#        'activity', 'name', 'age', 'time', 'species_', 'injury', 'fecha_limpia',
#        'fatal', 'sex', 'pais', 'rh_950mb', 'rh_900mb', 'rh_850mb', 'rh_800mb',
#        'rh_750mb', 'rh_700mb', 'rh_650mb', 'rh_600mb', 'rh_550mb', 'rh_500mb',
#        'rh_450mb', 'rh_400mb', 'rh_350mb', 'rh_300mb', 'rh_250mb', 'rh_200mb',
#        'wind_950mb', 'wind_900mb', 'wind_850mb', 'wind_800mb', 'wind_750mb',
#        'wind_700mb', 'wind_650mb', 'wind_600mb', 'wind_550mb', 'wind_500mb',
#        'wind_450mb', 'wind_400mb', 'wind_350mb', 'wind_300mb', 'wind_250mb',
#        'wind_200mb', 'index', 'timepoint', 'cloudcover', 'highcloud',
#        'midcloud', 'lowcloud', 'temp2m', 'lifted_index', 'rh2m',
#        'msl_pressure', 'prec_amount', 'snow_depth', 'wind10m.direction',
#        'wind10m.speed'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4395 entries, 0 to 4394
# Data columns (total 62 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   case_number        4394 non-null   object
#  1   year               4395 non-null   float64
#  2   type               4394 non-null   object
#  3   country            4395 non-null   object
#  4   area               4363 non-null   object
#  5   location           4276 non-null   object
#  6   activity           4066 non-null   object
#  7   name               4325 non-null   object
#  8   age                2681 non-null   object
#  9   time               2395 non-null   object
#  10  species_           2647 non-null   object
#  11  injury             4381 non-null   object
#  12  fecha_limpia       4148 non-null   object
#  13  fatal              3975 non-null   object
#  14  sex                4059 non-null   object
#  15  pais               4395 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# case_number           1
# year                  0
# type                  1
# country               0
# area                 32
#                      ..
# msl_pressure          0
# prec_amount           0
# snow_depth            0
# wind10m.direction     0
# wind10m.speed         0
# Length: 62, dtype: int64

# %% [markdown]
# Teníamos en mente que case_number fuera nuestra Primary Key, pero como tiene un nulo, aunque nuestro primer instinto fue eliminar el nulo, creemos que es mala práctica y vamos a crear otra Primary Key.

# %%
query_tabla_ataques = """
CREATE TABLE IF NOT EXISTS `tiburones`.`ataques` (
  `index_ataques` INT NOT NULL AUTO_INCREMENT,
  `case_number` VARCHAR(45) NULL,
  `year` FLOAT NULL,
  `type` VARCHAR(200) NULL,
  `country` VARCHAR(45) NULL,
  `area` VARCHAR(200) NULL,
  `location` VARCHAR(200) NULL,
  `activity` VARCHAR(2000) NULL,
  `name` VARCHAR(200) NULL,
  `age` VARCHAR(45) NULL,
  `time` VARCHAR(20) NULL,
  `species_` VARCHAR(45) NULL,
  `injury` VARCHAR(2000) NULL,
  `fecha_limpia` VARCHAR(3) NULL,
  `fatal` VARCHAR(10) NULL,
  `sex` VARCHAR(10) NULL,
  `pais` VARCHAR(45) NULL,

  PRIMARY KEY (`index_ataques`));

"""

# %%
crear_tabla_ataques = crear_insertar_tabla("tiburones", query_tabla_ataques)

# %% [markdown]
# tabla_ataques = crear_insertar_tabla("tiburones", query_tabla_tiburones)

# %%
query_tabla_clima = """
                            CREATE TABLE IF NOT EXISTS clima ( `index_clima` INT NOT NULL AUTO_INCREMENT,
                                                                `pais` VARCHAR(40),
                                                                `rh_950mb` FLOAT NOT NULL,
                                                                `rh_900mb` FLOAT NOT NULL,
                                                                `rh_850mb` FLOAT NOT NULL,
                                                                `rh_800mb` FLOAT NOT NULL,
                                                                `rh_750mb` FLOAT NOT NULL,
                                                                `rh_700mb` FLOAT NOT NULL,
                                                                `rh_650mb` FLOAT NOT NULL,
                                                                `rh_600mb` FLOAT NOT NULL,
                                                                `rh_550mb` FLOAT NOT NULL,
                                                                `rh_500mb` FLOAT NOT NULL,
                                                                `rh_450mb` FLOAT NOT NULL,
                                                                `rh_400mb` FLOAT NOT NULL,
                                                                `rh_350mb` FLOAT NOT NULL,
                                                                `rh_300mb` FLOAT NOT NULL,
                                                                `rh_250mb` FLOAT NOT NULL,
                                                                `rh_200mb` FLOAT NOT NULL,
                                                                `wind_950mb` FLOAT NOT NULL,
                                                                `wind_900mb` FLOAT NOT NULL,
                                                                `wind_850mb` FLOAT NOT NULL,
                                                                `wind_800mb` FLOAT NOT NULL,
                                                                `wind_750mb` FLOAT NOT NULL,
                                                                `wind_700mb` FLOAT NOT NULL,
                                                                `wind_650mb` FLOAT NOT NULL,
                                                                `wind_600mb` FLOAT NOT NULL,
                                                                `wind_550mb` FLOAT NOT NULL,
                                                                `wind_500mb` FLOAT NOT NULL,
                                                                `wind_450mb` FLOAT NOT NULL,
                                                                `wind_400mb` FLOAT NOT NULL,
                                                                `wind_350mb` FLOAT NOT NULL,
                                                                `wind_300mb` FLOAT NOT NULL,
                                                                `wind_250mb` FLOAT NOT NULL,
                                                                `wind_200mb` FLOAT NOT NULL,
                                                                `index` FLOAT NOT NULL,
                                                                `timepoint` FLOAT NOT NULL,
                                                                `cloudcover` FLOAT NOT NULL,
                                                                `highcloud` FLOAT NOT NULL,
                                                                `midcloud` FLOAT NOT NULL,
                                                                `lowcloud` FLOAT NOT NULL,
                                                                `temp2m` FLOAT NOT NULL,
                                                                `lifted_index` FLOAT NOT NULL,
                                                                `rh2m` FLOAT NOT NULL,
                                                                `msl_pressure` FLOAT NOT NULL,
                                                                `prec_amount` FLOAT NOT NULL,
                                                                `snow_depth` FLOAT NOT NULL,
                                                                `wind10m.direction` FLOAT NOT NULL,
                                                                `wind10m.speed` FLOAT NOT NULL,

                                                                PRIMARY KEY (`index_clima`));"""

# %%
tabla_clima = crear_insertar_tabla("tiburones",  query_tabla_clima)

# %%
for indice, valor in df.iterrows():
    query_datos_ataques = f"""INSERT INTO ataques (`case_number`, `year`, `type`, `country`, `area`, `location`,`activity`, 
                                                    `name`, `age`, `time`, `species_`, `injury`, `fecha_limpia`, `fatal`, `sex`, `pais`) 
                                                    VALUES ("{valor['case_number']}", "{valor['year']}", "{valor['type']}","{valor['country']}", 
                                                    "{valor['area']}", "{valor['location']}", "{valor['activity']}","{valor['name']}", 
                                                    "{valor['age']}", "{valor['time']}", "{valor['species_']}", "{valor['injury']}", 
                                                    "{valor['fecha_limpia']}", "{valor['fatal']}", "{valor['sex']}", "{valor['pais']}");"""

    crear_insertar_tabla("tiburones", query_datos_ataques)
# Out:
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# Message Incorrect integer value: 'nan' for column 'age' at row 1
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# Message Incorrect integer value: 'nan' for column 'age' at row 1
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# Message Incorrect integer value: 'nan' for column 'age' at row 1
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# Message Incorrect integer value: 'nan' for column 'age' at row 1
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# Message Incorrect integer value: 'nan' for column 'age' at row 1
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# ...

# %% [markdown]
# Hemos tenido muchos problemas de todo tipo para insertar los datos y al final no lo hemos conseguido.
#
# - Con afan de solventarl os problemas hemos intentado varias soluciones, pero ninguna ha dado resultado, las dejamos todas a continuación.

# %%
# Como uno de los problemas hacía referencia a los nulos en la columna "age" hemos intentado sustituir los nulos, pero no ha funcionado.

# df[df["age"]== np.nan] = "SQL SUCKS" 🤢

# %%
# Hemos probado esto de internet...


#LOAD DATA INFILE 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/employees.csv'
#INTO TABLE EmployeeS (EmployeeId, LastName, . . . , @salary)
#    SET salary = (CASE WHEN @salary <> 'NULL' THEN CAST(@salary AS FLOAT) END)
#FIELDS TERMINATED BY ','
#IGNORE 1 ROWS;

# %%
# Y hasta unas compañeras nos han mandado su código para que lo probemos y también está mal, auqnue a ellas les funciona.

## for indice, fila in df.iterrows():
##     # itreamos por el dataframe.
##     # lo valores que introduciremos serán los del dataframe que estamos iterando, por lo que usaremos los formats de los strings.
##     query_x = f"""
##             INSERT INTO ataques (case_number, year, type, country, area, location, activity, name, age, time, species_, injury, fecha_limpia, fatal, sex, pais)
##             VALUES ( "{fila["case_number"]}", "{fila["year"]}", "{fila['type']}", "{fila['country']}", "{fila['area']}", "{fila['location']}", "{fila["activity"]}",
##             "{fila['name']}", "{fila["age"]}", "{fila["time"]}","{fila["species_"]}","{fila['injury']}", "{fila["fecha_limpia"]}","{fila['fatal']}", "{fila["pais"]}","{fila['sex']}");
##             """
##     # una vez definida la query llamamos a la función que nos inserta los datos.
##     crear_insertar_tabla("tiburones", query_x)
##
# Out:
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# Message Incorrect integer value: 'nan' for column 'age' at row 1
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# Message Incorrect integer value: 'nan' for column 'age' at row 1
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# Message Incorrect integer value: 'nan' for column 'age' at row 1
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# Message Incorrect integer value: 'nan' for column 'age' at row 1
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# Message Incorrect integer value: 'nan' for column 'age' at row 1
# 1366 (HY000): Incorrect integer value: 'nan' for column 'age' at row 1
# error code: 1366
# SQLSTATE HY000
# ...

# %% [markdown]
# Llegamos a la conclusión de que , hay un error que no sabemos encontrar, los datos están mal o SQL nos odia...😭
#
# También llegamos a la conclusión de que estamos teniendo el pair paranormal y no podemos luchar contra fuerzas sobrenaturales 👻 #Desconocidoooor
#
# Nos habría gustado poder cumplir con todos los objetivos pero no hemos podido asi que no nos queda otra que tomarlo con humor.
