# %%
import sidetable
import pandas as pd

# %%
# Usaremos el df ya filtrado de Limpieza de datos I, ya que ahí ya eliminamos columnas.

df = pd.read_csv("datos/attacks_pandas7.csv", index_col = 0)

# %% [markdown]
# Usad la librería sidetable para:
# - Explorar los valores nulos.

# %%
df.stb.missing()
# Out:
#                     missing  total    percent
# siglo                  6287   7789  80.716395
# time                   6277   7789  80.588009
# age                    6271   7789  80.510977
# species_               6243   7789  80.151496
# location               6168   7789  79.188599
# area                   6163   7789  79.124406
# activity               6148   7789  78.931827
# sex_                   6131   7789  78.713570
# country                6127   7789  78.662216
# name                   6126   7789  78.649377
# type                   6117   7789  78.533830
# href                   6117   7789  78.533830
# year                   6117   7789  78.533830
# mes                    2395   7789  30.748491
# fatal_(y/n)_limpio     2111   7789  27.102324
# fatal_(y/n)            2038   7789  26.165105
# injury                 1531   7789  19.655925
# date                   1503   7789  19.296444
# case_number               1   7789   0.012839
# ...

# %% [markdown]
# Explorad la columna de country y reportad los resultados solo para aquellas categorías que incluyan el 70% de los datos.

# %%
df.stb.freq(["country"], thresh= 70)
# Out:
#      country  count    percent  cumulative_count  cumulative_percent
# 0        USA    741  44.584838               741           44.584838
# 1  AUSTRALIA    343  20.637786              1084           65.222623
# 2     others    578  34.777377              1662          100.000000

# %% [markdown]
# Explorad la columna country en relación al sexo, filtrando de nuevo por aquellas categorías que incluyan el 70% de los datos.

# %%
df.stb.freq(["country", "sex"], thresh= 70)
# Out:
#         country     sex  count    percent  cumulative_count  \
# 0           USA       M    609  36.642599               609
# 1     AUSTRALIA       M    309  18.592058               918
# 2  SOUTH AFRICA       M    224  13.477738              1142
# 3        others  others    520  31.287605              1662
#
#    cumulative_percent
# 0           36.642599
# 1           55.234657
# 2           68.712395
# 3          100.000000

# %% [markdown]
# Haced los mismo para la columna activity en relación a la columna fatal. En este caso filtrad y mostrad los datos que incluyan el 60% de los datos.

# %%
df.stb.freq(["activity", "fatal_(y/n)_limpio"], thresh= 60)
# Out:
#    activity fatal_(y/n)_limpio  count    percent  cumulative_count  \
# 0   Surfing                  N     51  32.278481                51
# 1  Swimming                  N     17  10.759494                68
# 2    Wading                  N     10   6.329114                78
# 3   Fishing                  N     10   6.329114                88
# 4    others             others     70  44.303797               158
#
#    cumulative_percent
# 0           32.278481
# 1           43.037975
# 2           49.367089
# 3           55.696203
# 4          100.000000

# %% [markdown]
# Por último, realizad este análisis para la columna fecha en relación a la columna fatal. Mostrad solo los resultados para las categorías que incluyan el 60% de los datos.

# %%
df.stb.freq(["mes", "fatal_(y/n)_limpio"], thresh= 60)
# Out:
#       mes fatal_(y/n)_limpio  count    percent  cumulative_count  \
# 0     Jul                  N    446   9.113200               446
# 1     Aug                  N    398   8.132407               844
# 2     Sep                  N    370   7.560278              1214
# 3     Jun                  N    334   6.824683              1548
# 4     Jan                  N    329   6.722517              1877
# 5     Oct                  N    315   6.436453              2192
# 6     Apr                  N    289   5.905190              2481
# 7     Mar                  N    270   5.516960              2751
# 8  others             others   2143  43.788312              4894
#
#    cumulative_percent
# 0            9.113200
# 1           17.245607
# 2           24.805885
# 3           31.630568
# 4           38.353085
# 5           44.789538
# 6           50.694728
# 7           56.211688
# 8          100.000000

# %% [markdown]
# ###  Conclusiones:
#
# En relación a los valores nulos:
# - Debatid entre vosotras qué haríais con los valores nulos, ¿los quitaríais o los reemplazaríais con un valor que nosotras decidiremos?

# %% [markdown]
# Creemos que como tenemos una gran cantidad de nulos deberíamos filtrarlos de alguna forma para que los resultados saliesen lo más fiables posibles.
#
# La mejor manera sería poder filtrar las filas que todas sus categorías estuviesen "vacías", no obstante no sabemos cual sería la forma correcta de hacer ese filtro.
#
# Otra opción sería filtrar nulos en base a las columnas que más no interesan para probar nuestras hipotesis, que serían la de country, las de fecha, species... pero por cual priorizamos es algo que tampoco tenemos claro.
