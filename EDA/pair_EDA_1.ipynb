# %% [markdown]
# ### Pair Programming — EDA

# %% [markdown]
# ¿Es Australia el sitio más peligroso y letal para estar relajada en la playa?
#
# ¿Hay diferencias entre los países en los ataques a hombres y mujeres?
#
# ¿Cuáles son las edades que más sufren ataques?
#
# Independientemente de la edad, ¿sufren los hombres más ataques que las mujeres?
#
# ¿En qué mes ocurren más ataques?
#
# ¿Cuál es la relación entre la especie y el tipo de ataque (si es fatal o no)?
#
# ¿Cómo han evolucionado los ataques a lo largo del tiempo?

# %%
import pandas as pd

# %%
df = pd.read_csv("datos/attacks_pandas7.csv")

# %%
# 1. Haced una exploración inicial del dataframe:
# ¿Cuál es el número de filas y columnas?

df.shape
# Out:
# (7789, 22)

# %%
# ¿Cuál es el porcentaje de valores nulos en cada columna? Presenta los resultados en un dataframe, donde las columnas sean el nombre de las variables y el porcentaje de nulos.

df.isnull().sum()*100/df.shape[0]
# Out:
# Unnamed: 0             0.000000
# case_number            0.012839
# unnamed:_0             0.000000
# year                  78.533830
# type                  78.533830
# country               78.662216
# area                  79.124406
# location              79.188599
# activity              78.931827
# name                  78.649377
# sex_                  78.713570
# age                   80.510977
# time                  80.588009
# species_              80.151496
# href                  78.533830
# siglo                 80.716395
# fatal_(y/n)           26.165105
# injury                19.655925
# date                  19.296444
# mes                   30.748491
# fatal_(y/n)_limpio    27.102324
# sex                    0.000000
# dtype: float64

# %%
# ¿Qué tipos de datos hay en cada columna?

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          7789 non-null   int64
#  1   case_number         7788 non-null   object
#  2   unnamed:_0          7789 non-null   int64
#  3   year                1672 non-null   float64
#  4   type                1672 non-null   object
#  5   country             1662 non-null   object
#  6   area                1626 non-null   object
#  7   location            1621 non-null   object
#  8   activity            1641 non-null   object
#  9   name                1663 non-null   object
#  10  sex_                1658 non-null   object
#  11  age                 1518 non-null   object
#  12  time                1512 non-null   object
#  13  species_            1546 non-null   object
#  14  href                1672 non-null   object
# ...

# %%
# Extraed la información general del dataframe.

df.describe()
# Out:
#         Unnamed: 0   unnamed:_0         year
# count  7789.000000  7789.000000  1672.000000
# mean   3894.000000  3085.494672  1832.688397
# std    2248.634956  1791.788290   528.969901
# min       0.000000     0.000000     0.000000
# 25%    1947.000000  1555.000000  1964.000000
# 50%    3894.000000  2973.000000  1997.000000
# 75%    5841.000000  4587.000000  2008.000000
# max    7788.000000  6301.000000  2018.000000

# %%
#2. Cread dos dataframes nuevos, uno que incluya solo las variables categóricas y otro que incluya solo las variables
# numéricas.

df_categoricas = df.select_dtypes(include = "object")
df_numericas = df.select_dtypes(exclude = "object")

# %%
# ¿Cuáles son los principales estádisticos de los dataframes?

df_categoricas.describe()
# Out:
#        case_number        type country     area  \
# count         7788        1672    1662     1626
# unique        6287           6      95      236
# top     1959.11.22  Unprovoked     USA  Florida
# freq             2        1432     741      346
#
#                                 location activity  name  sex_   age   time  \
# count                               1621     1641  1663  1658  1518   1512
# unique                              1310      404  1536     3    94    248
# top     New Smyrna Beach, Volusia County  Surfing  male     M    19  11h00
# freq                                  73      426    97  1435    70     74
#
#            species_                                               href  \
# count          1546                                               1672
# unique          856                                               1672
# top     White shark  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
df_categoricas.head(2)
# Out:
#     case_number        type country        area                     location  \
# 0    2018.06.25     Boating     USA  California  Oceanside, San Diego County
# 1  2018.06.03.a  Unprovoked  BRAZIL  Pernambuco        Piedade Beach, Recife
#
#    activity                    name sex_ age            time     species_  \
# 0  Paddling             Julie Wolfe    F  57           18h00  White shark
# 1  Swimming  Jose Ernesto da Silva     M  18  Late afternoon  Tiger shark
#
#                                                 href      siglo fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI           N
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo XXI           Y
#
#                                               injury         date  mes  \
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018  Jun
# 1                                              FATAL  03-Jun-2018  Jun
#
#   fatal_(y/n)_limpio sex
# 0                  N   F
# ...

# %%
df_numericas.describe()
# Out:
#         Unnamed: 0   unnamed:_0         year
# count  7789.000000  7789.000000  1672.000000
# mean   3894.000000  3085.494672  1832.688397
# std    2248.634956  1791.788290   528.969901
# min       0.000000     0.000000     0.000000
# 25%    1947.000000  1555.000000  1964.000000
# 50%    3894.000000  2973.000000  1997.000000
# 75%    5841.000000  4587.000000  2008.000000
# max    7788.000000  6301.000000  2018.000000

# %%
lista_vacia = []
lista_vacia2 = []

df_unicos = pd.DataFrame()

for col in df_categoricas.columns:
    #df[col].unique()
    #df_unicos.append(df[col].unique)
    df_unicos_2 = pd.DataFrame(df[col].value_counts())
    df_unicos_2["variable"] = col
    df_unicos = pd.concat([df_unicos, df_unicos_2], axis = 0)
    print(df_unicos_2)
# Out:
#               case_number     variable
# 1959.11.22              2  case_number
# 1985.09.05              2  case_number
# 1979.05.05              2  case_number
# 1979.11.27              2  case_number
# 1980.00.00.b            2  case_number
# ...                   ...          ...
# 1996.07.20              1  case_number
# 1996.07.21              1  case_number
# 1996.07.23.a            1  case_number
# 1996.07.23.b            1  case_number
# xx                      1  case_number
#
# [6287 rows x 2 columns]
#               type variable
# Unprovoked    1432     type
# Provoked       115     type
# Invalid         92     type
# Boating         17     type
# Sea Disaster    12     type
# Boat             4     type
#                     country variable
# USA                     741  country
# AUSTRALIA               343  country
# SOUTH AFRICA            234  country
# BAHAMAS                  29  country
# NEW ZEALAND              21  country
# ...

# %%
df_unicos
# Out:
#               case_number            variable  type  country  area  location  \
# 1959.11.22            2.0         case_number   NaN      NaN   NaN       NaN
# 1985.09.05            2.0         case_number   NaN      NaN   NaN       NaN
# 1979.05.05            2.0         case_number   NaN      NaN   NaN       NaN
# 1979.11.27            2.0         case_number   NaN      NaN   NaN       NaN
# 1980.00.00.b          2.0         case_number   NaN      NaN   NaN       NaN
# ...                   ...                 ...   ...      ...   ...       ...
# 28                    NaN                 mes   NaN      NaN   NaN       NaN
# N                     NaN  fatal_(y/n)_limpio   NaN      NaN   NaN       NaN
# Y                     NaN  fatal_(y/n)_limpio   NaN      NaN   NaN       NaN
# M                     NaN                 sex   NaN      NaN   NaN       NaN
# F                     NaN                 sex   NaN      NaN   NaN       NaN
#
# ...

# %%
# Extraed los valores únicos su frecuencia.

lista_vacia = []
lista_vacia2 = []

for col in df_categoricas.columns:
    print(df[col].unique())
    lista_vacia.append(df[col].unique()[:])
    print("-----------")
    print(df[col].value_counts())
    lista_vacia2.append(df[col].value_counts())
    print("-----------")
# Out:
# ['2018.06.25' '2018.06.03.a' '2018.05.26.b' ... '1801.12.18.R' '0' 'xx']
# -----------
# 1959.11.22      2
# 1985.09.05      2
# 1979.05.05      2
# 1979.11.27      2
# 1980.00.00.b    2
#                ..
# 1996.07.20      1
# 1996.07.21      1
# 1996.07.23.a    1
# 1996.07.23.b    1
# xx              1
# Name: case_number, Length: 6287, dtype: int64
# -----------
# ['Boating' 'Unprovoked' 'Provoked' 'Invalid' 'Sea Disaster' 'Boat' nan]
# -----------
# Unprovoked      1432
# Provoked         115
# Invalid           92
# Boating           17
# Sea Disaster      12
# Boat               4
# Name: type, dtype: int64
# -----------
# ['USA' 'BRAZIL' 'AUSTRALIA' 'ENGLAND' 'COSTA RICA' 'MALDIVES'
#  'SOUTH AFRICA' 'CUBA' 'SPAIN' 'BAHAMAS' 'INDONESIA' 'EGYPT' 'NEW ZEALAND'
#  'FRENCH POLYNESIA' 'NEW CALEDONIA' 'ECUADOR' 'THAILAND' 'REUNION'
#  'MEXICO' 'JAMAICA' 'ITALY' 'PAPUA NEW GUINEA' 'RUSSIA' 'SEYCHELLES'
#  'VIETNAM' 'GUAM' 'MOZAMBIQUE' 'SCOTLAND' 'UNITED KINGDOM' 'TAIWAN'
# ...

# %%
df_lista_vacia = pd.DataFrame(lista_vacia)

# %%
df_lista_vacia.head()
# Out:
#                           0                      1     \
# 0                   2018.06.25           2018.06.03.a
# 1                      Boating             Unprovoked
# 2                          USA                 BRAZIL
# 3                   California             Pernambuco
# 4  Oceanside, San Diego County  Piedade Beach, Recife
#
#                            2                3               4     \
# 0                  2018.05.26.b       2018.05.24    2018.05.13.a
# 1                      Provoked          Invalid    Sea Disaster
# 2                     AUSTRALIA          ENGLAND      COSTA RICA
# 3                       Florida       Queensland        Cornwall
# 4  Cocoa Beach, Brevard  County  Cairns Aquarium  Off Land's End
#
#            5                        6                  7     \
# 0  2018.04.28.b             2018.04.25.a         2018.04.23
# 1          Boat                      NaN               None
# 2      MALDIVES             SOUTH AFRICA               CUBA
# ...

# %%
#unicos_categoricas = pd.DataFrame(lista_vacia2)

# %%
unicos_categoricas.head(2)
# Out:
#              1959.11.22  1985.09.05  1979.05.05  1979.11.27  1980.00.00.b  \
# case_number         2.0         2.0         2.0         2.0           2.0
# type                NaN         NaN         NaN         NaN           NaN
#
#              1980.01.10  1980.01.15  1980.01.31  1980.04.00  1980.05.15  ...  \
# case_number         2.0         2.0         2.0         2.0         2.0  ...
# type                NaN         NaN         NaN         NaN         NaN  ...
#
#              Oct  Dec  Mar  Nov  May  Feb  July  Sept  Ap  March
# case_number  NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN    NaN
# type         NaN  NaN  NaN  NaN  NaN  NaN   NaN   NaN NaN    NaN
#
# [2 rows x 21911 columns]

# %%
df_bonus = pd.DataFrame(columns = ["variable", "n_uniques"])

# %%
df_bonus.head(2)
# Out:
# Empty DataFrame
# Columns: [variable, n_uniques]
# Index: []

# %%
df_categoricas.columns
# Out:
# Index(['case_number', 'type', 'country', 'area', 'location', 'activity',
#        'name', 'sex_', 'age', 'time', 'species_', 'href', 'siglo',
#        'fatal_(y/n)', 'injury', 'date', 'mes', 'fatal_(y/n)_limpio', 'sex'],
#       dtype='object')

# %%
for x in list(df_categoricas.columns):
    df_bonus = df_bonus.append([{"variable": x}], ignore_index=True)
# Out:
# /tmp/ipykernel_23466/1940991254.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_bonus = df_bonus.append([{"variable": x}], ignore_index=True)
# /tmp/ipykernel_23466/1940991254.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_bonus = df_bonus.append([{"variable": x}], ignore_index=True)
# /tmp/ipykernel_23466/1940991254.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_bonus = df_bonus.append([{"variable": x}], ignore_index=True)
# /tmp/ipykernel_23466/1940991254.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_bonus = df_bonus.append([{"variable": x}], ignore_index=True)
# ...

# %%
df_bonus.head()
# Out:
#       variable n_uniques
# 0  case_number       NaN
# 1         type       NaN
# 2      country       NaN
# 3         area       NaN
# 4     location       NaN

# %%
for x in df_lista_vacia:
    for a in x:
    #df_bonus = df_bonus.append([{"n_uniques": x}], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_23466/2016609199.py in <module>
# ----> 1 for x[1:] in df_lista_vacia:
#       2     print(x)
#       3         #df_bonus = df_bonus.append([{"n_uniques": x}], ignore_index=True)
#
# TypeError: 'int' object does not support item assignment

# %%
df_bonus.head()
# Out:
#       variable n_uniques
# 0  case_number       NaN
# 1         type       NaN
# 2      country       NaN
# 3         area       NaN
# 4     location       NaN

# %%
# BONUS presenta los resultados en un dataframe. Os deberá quedar algo como esto:

df_nuevo = pd.concat(df_categoricas, df_numericas)
# Out:
# /tmp/ipykernel_23466/3735341467.py:3: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   df_nuevo = pd.concat(df_categoricas, df_numericas)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_23466/3735341467.py in <module>
#       1 # BONUS presenta los resultados en un dataframe. Os deberá quedar algo como esto:
#       2
# ----> 3 df_nuevo = pd.concat(df_categoricas, df_numericas)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.head(2)

# %%
pd.options.display.max_columns = None

# %% [markdown]
# - **¿Hay alguna columna que no tenga sentido su tipo de datos?**
#
# El Unnamed: 0 no nos sirve, deberíamos haberlo quitado. También la columna de "type" no es muy necesaria, dado que existe una que nos ofrece información similar y más clara, así como la de "activity", que no nos resulta muy útil. La columna "time" también es poco provechosa dado que los datos están introducidos de formas muy diversas y sería difícil acceder a ellos incluso usando RegEx. La columna href tampoco nos es útil dada la forma en que estamos analizndo los datos (sería demasiado complicado leer todos los pdf). La columna de "sex" tampoco aporta nada, aparentemente, y la de "fatal_(y/n)" ha sido mejorada en "fatal_(y/n)_limpio".
#
# - **¿Hay alguna columna que no tenga sentido su nombre?**
#
# La columna "area" es demasiado general, alude igualmente a Estados enteros como a ciudades.
#
# - **¿Hay alguna columna que no tenga sentido su contenido?**
#
# No, nos parece que son acordes.
#
# - **¿Hay alguna columna que tenga demasiadas categorías o valores que nos pueda hacer difícil trabajar con ella?**
#
# Las columnas de "species_", "activity" y "time" parecen complicadas de trabajar con ellas a la hora de filtrar los datos.
